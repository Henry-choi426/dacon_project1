# %% [markdown]
# ## 사용 패키지

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# %%
from pycaret.regression import *

# %% [markdown]
# ## 데이터 로드

# %%
# 기존 데이터 Load

train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
submission = pd.read_csv('./data/sample_submission.csv')

# %%
# 식단 전처리 데이터 Load

train_lunch = pd.read_csv('train_.csv')
test_lunch = pd.read_csv('test_.csv')
train_dinner = pd.read_csv('train_night.csv')
test_dinner = pd.read_csv('test_night.csv')

train_lunch.drop(columns = ['Unnamed: 0'], inplace = True)
test_lunch.drop(columns = ['Unnamed: 0'], inplace = True)
train_dinner.drop(columns = ['Unnamed: 0'], inplace = True)
test_dinner.drop(columns = ['Unnamed: 0'], inplace = True)

train_lunch.dropna(axis = 0, inplace =True)
train_dinner.dropna(axis = 0, inplace =True)

# %% [markdown]
# ## 강수 데이터 load 및 전처리

# %% [markdown]
# ### 2010~ 2020 강수 데이터 Load

# %%
import glob
outputs = glob.glob('진주강수량/SURFACE*.csv')

temp_data = pd.DataFrame(columns=['일시','강수량(mm)'])

for output in outputs:
    temp = pd.read_csv(output, encoding='cp949')
    temp['강수량(mm)'].fillna(0, inplace= True)
    temp_data =temp_data.append(temp[['일시','강수량(mm)']])

# %%
temp_data = temp_data.fillna(method = 'bfill')
temp_data.isnull().sum()
# Out:
# 일시         0
# 강수량(mm)    0
# dtype: int64

# %% [markdown]
# ### 2021 강수 데이터 Load

# %%
newest = temp = pd.read_csv('진주강수량\\충무공동_강수_202101_202110.csv', encoding='cp949')

# %%
newest.columns=['일시','시간','강수량(mm)','월']
newest.dropna(axis = 0, inplace = True)

# %%
import datetime
from dateutil.relativedelta import relativedelta

newest['시간'] = newest.apply(lambda x : int(x['시간']//100), axis= 1)
newest['일시'] = newest.apply(lambda x : datetime.datetime.combine(pd.to_datetime('2020-12-31')+datetime.timedelta(days=int(x['일시'].strip()))+relativedelta(months=x['월']), datetime.time(x['시간'],0,0)),axis = 1)

# %%
newest.drop(columns = ['시간','월'], inplace = True)

# %%
newest.head()
# Out:
#                    일시  강수량(mm)
# 0 2021-01-01 00:00:00      0.0
# 1 2021-01-01 01:00:00      0.0
# 2 2021-01-01 02:00:00      0.0
# 3 2021-01-01 03:00:00      0.0
# 4 2021-01-01 04:00:00      0.0

# %% [markdown]
# ### 강수 데이터 Append

# %%
temp_data = temp_data.append(newest)

# %%
temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109497 entries, 0 to 2882
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   일시       109497 non-null  object
#  1   강수량(mm)  109497 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.5+ MB

# %% [markdown]
# ### 점심 강수 데이터 추출

# %%
# 11시 ~ 14시 사이 강수량이 있는 경우 1

df = temp_data.copy()
df['일시'] = df['일시'].astype('datetime64[ns]')
df.set_index(df['일시'],drop=True,inplace = True)
df.drop(columns = ['일시'], inplace = True)

lunch_df = df.between_time('11:00','14:00', include_start = True, include_end = True, axis = None )
lunch_df.reset_index(drop=False,inplace = True)

lunch_df['일시'] = pd.to_datetime(lunch_df['일시']).dt.date
lunch_result = lunch_df.groupby('일시')['강수량(mm)'].aggregate(['sum']).reset_index()

lunch_result['강수여부'] = lunch_result.apply(lambda x : 1 if x['sum'] > 0 else 0,axis = 1)

# %%
lunch_result.columns =['일자','강수량','강수여부']
lunch_result.drop(columns = ['강수량'], inplace = True)

# %%
lunch_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4138 entries, 0 to 4137
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      4138 non-null   object
#  1   강수여부    4138 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 64.8+ KB

# %% [markdown]
# ### 저녁 강수 데이터 추출

# %%
df = temp_data.copy()

df['일시'] = df['일시'].astype('datetime64[ns]')
df.set_index(df['일시'],drop=True,inplace = True)
df.drop(columns = ['일시'], inplace = True)

dinner_df = df.between_time('17:00','20:00', include_start = True, include_end = True, axis = None )
dinner_df.reset_index(drop=False,inplace = True)

dinner_df['일시'] = pd.to_datetime(dinner_df['일시']).dt.date
dinner_result = dinner_df.groupby('일시')['강수량(mm)'].aggregate(['sum']).reset_index()

dinner_result['강수여부'] = dinner_result.apply(lambda x : 1 if x['sum'] > 0 else 0,axis = 1)

# %%
dinner_result.columns =['일자','강수량','강수여부']
dinner_result.drop(columns = ['강수량'], inplace = True)

# %%
dinner_result.sum()
# Out:
# 강수여부    504
# dtype: int64

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# 1. LabelEncoding 및 MinMaxScaler
# 2. 휴일 전, 휴일 후 column 추가
# 3. 강수량 column 추가

# %% [markdown]
# ### LabelEncoding

# %%
# train_lunch['요일'] = train['요일'].map({'월':0, '화':1, '수':2, '목':3, '금':4})
# test_lunch['요일'] = test['요일'].map({'월':0, '화':1, '수':2, '목':3, '금':4})

# train_dinner['요일'] = train['요일'].map({'월':0, '화':1, '수':2, '목':3, '금':4})
# test_dinner['요일'] = test['요일'].map({'월':0, '화':1, '수':2, '목':3, '금':4})

# %%
train_lunch['요일'] = train['요일'].astype('category')
test_lunch['요일'] = test['요일'].astype('category')

train_dinner['요일'] = train['요일'].astype('category')
test_dinner['요일'] = test['요일'].astype('category')

# %% [markdown]
# ### MinMaxScaling(Tree구조 사용 안 할 경우)

# %%
# from sklearn.preprocessing import MinMaxScaler

# %%
# merge_train.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  현본사소속재택근무자수     밥      국      메인  \
# 0  2016-02-01  월   2601      50     150          0.0     밥  오징어찌개    쇠불고기
# 1  2016-02-02  화   2601      50     173          0.0     밥   김치찌개   가자미튀김
# 2  2016-02-03  수   2601      56     180          0.0  카레덮밥   팽이장국    치킨핑거
# 3  2016-02-04  목   2601     104     220          0.0     밥  쇠고기무국   주꾸미볶음
# 4  2016-02-05  금   2601     278     181          0.0     밥     떡국  돈육씨앗강정
#
#       중식계
# 0  1039.0
# 1   867.0
# 2  1017.0
# 3   978.0
# 4   925.0

# %%
# train['본사정원수'] = train['본사정원수']-train['본사휴가자수']-train['본사출장자수']-train['현본사소속재택근무자수']
# test['본사정원수'] = test['본사정원수']-test['본사휴가자수']-test['본사출장자수']-test['현본사소속재택근무자수']

# %%
# train['휴일전'] = train.apply(lambda x: 1 if x['요일'] == 4 else 0 , axis = 1) 
# train['휴일후'] = train.apply(lambda x: 1 if x['요일'] == 0 else 0 , axis = 1)

# test['휴일전'] = test.apply(lambda x: 1 if x['요일'] == 4 else 0 , axis = 1) 
# test['휴일후'] = test.apply(lambda x: 1 if x['요일'] == 0 else 0 , axis = 1)

# %%
# train[['본사정원수','본사시간외근무명령서승인건수']] = scaler.fit_transform(train[['본사정원수', '본사시간외근무명령서승인건수']])
# test[['본사정원수', '본사시간외근무명령서승인건수']] = scaler.transform(test[['본사정원수', '본사시간외근무명령서승인건수']])

# %%
# train['본사정원수'].max(),train['본사정원수'].min(),test['본사정원수'].max(),test['본사정원수'].min()
# Out:
# (2921.0, 1372.0, 2448.0, 2068.0)

# %% [markdown]
# ## 일자 기준 기존 데이터와 강수 데이터 Merge

# %%
train_lunch['일자'] = pd.to_datetime(train_lunch['일자'])
test_lunch['일자'] = pd.to_datetime(test_lunch['일자'])
train_dinner['일자'] = pd.to_datetime(train_dinner['일자'])
test_dinner['일자'] = pd.to_datetime(test_dinner['일자'])

lunch_result['일자'] = pd.to_datetime(lunch_result['일자'])
dinner_result['일자'] = pd.to_datetime(dinner_result['일자'])

# %%
train_lunch = pd.merge(left = train_lunch , right = lunch_result, how = "inner", on = "일자")
train_dinner = pd.merge(left = train_dinner , right = dinner_result, how = "inner", on = "일자")

test_lunch = pd.merge(left = test_lunch , right = lunch_result, how = "inner", on = "일자")
test_dinner = pd.merge(left = test_dinner , right = dinner_result, how = "inner", on = "일자")

# %%
train_lunch[train_lunch['요일'].isnull()]
# Out:
# Empty DataFrame
# Columns: [일자, 요일, 본사정원수, 본사휴가자수, 본사출장자수, 현본사소속재택근무자수, 밥, 국, 메인, 중식계, 강수여부]
# Index: []

# %%
train_dinner[train_dinner['요일'].isnull()]
# Out:
#             일자   요일  본사정원수  본사휴가자수  본사출장자수  현본사소속재택근무자수  밥     국       메인  \
# 967 2020-03-11  NaN   2950      74     197         23.0  밥  부대찌개  등갈비오븐구이
#
#        석식계  강수여부
# 967  487.0     0

# %%
# 요일을 category 데이터로 변환 시 수요일 하루 데이터가 누락되는 현상 발생. 임의로 추가

train_dinner['요일'].fillna('수', inplace = True)

# %%
test_dinner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   일자              50 non-null     datetime64[ns]
#  1   요일              50 non-null     category
#  2   본사정원수           50 non-null     int64
#  3   본사휴가자수          50 non-null     int64
#  4   본사출장자수          50 non-null     int64
#  5   본사시간외근무명령서승인건수  50 non-null     int64
#  6   현본사소속재택근무자수     50 non-null     float64
#  7   밥               50 non-null     object
#  8   국               50 non-null     object
#  9   메인              50 non-null     object
#  10  강수여부            50 non-null     int64
# dtypes: category(1), datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 4.5+ KB

# %%
# 중식계를 석식계 예측의 input으로 설정
train_dinner['중식계'] = train_lunch['중식계']

# %%
# 월 일 데이터 추가
train_lunch['month'] = train_lunch['일자'].dt.month
train_lunch['day'] = train_lunch['일자'].dt.day.astype('category')

train_dinner['month'] = train_dinner['일자'].dt.month
train_dinner['day'] = train_dinner['일자'].dt.day.astype('category')

test_lunch['month'] = test_lunch['일자'].dt.month
test_lunch['day'] = test_lunch['일자'].dt.day.astype('category')

test_dinner['month'] = test_dinner['일자'].dt.month
test_dinner['day'] = test_dinner['일자'].dt.day.astype('category')

# %% [markdown]
# ## 점심과 저녁을 식수 인원을 예측할 2개 모델 생성

# %%
# 점심 데이터 pycaret setup
setup_lunch = setup(data=train_lunch,target='중식계',ignore_features=['일자'])
# Out:
# <style  type="text/css" >
# #T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow0_col1" class="data row0 col1" >7418</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow1_col1" class="data row1 col1" >중식계</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow2_col1" class="data row2 col1" >(1204, 13)</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow5_col1" class="data row5 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow9_col1" class="data row9 col1" >(842, 564)</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow10_col1" class="data row10 col1" >(362, 564)</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5dlevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_b828a784_3bd5_11ec_b072_fa2819a1cc5drow18_col1" cl

# %%
# 저녁 데이터 pycaret setup (점심 예측 모델 생성 및 예측 완료 후 사용)
setup_dinner = setup(data=train_dinner,target='석식계',ignore_features=['일자'])
# Out:
# <style  type="text/css" >
# #T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow0_col1" class="data row0 col1" >5584</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow1_col1" class="data row1 col1" >석식계</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow2_col1" class="data row2 col1" >(1169, 14)</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow4_col1" class="data row4 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow5_col1" class="data row5 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow9_col1" class="data row9 col1" >(818, 640)</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow10_col1" class="data row10 col1" >(351, 640)</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5dlevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_759810ee_3bd6_11ec_8320_fa2819a1cc5drow18_col1" cl

# %%
best = compare_models(sort = 'MAE')
# Out:
# <style  type="text/css" >
#     #T_4c14b59d_3bab_11ec_b836_fa2819a1cc5d th {
#           text-align: left;
#     }#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow0_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow1_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow1_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow1_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow1_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow1_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow1_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow1_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow2_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow2_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow2_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow2_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow2_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow2_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow2_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow3_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow3_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow3_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow3_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow3_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow3_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow3_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow4_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow4_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow4_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow4_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow4_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow4_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow4_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow5_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow5_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow5_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow5_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow5_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow5_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow5_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow6_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow6_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow6_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow6_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow6_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow6_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow6_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow7_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow7_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow7_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow7_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow7_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow7_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow7_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow8_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow8_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow8_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow8_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow8_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow8_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow8_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow9_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow9_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow9_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow9_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow9_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow9_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow9_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow10_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow10_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow10_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow10_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow10_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow10_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow10_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow11_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow11_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow11_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow11_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow11_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow11_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow11_col6,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow12_col0,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow12_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow12_col2,#T_4c14b5 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow0_col1,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow0_col2,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow0_col3,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow0_col4,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow0_col5,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow0_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow1_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow2_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow3_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow4_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow5_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow6_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow7_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow8_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow9_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow10_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow12_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow13_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow14_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow15_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow16_col7,#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_4c14b59d_3bab_11ec_b836_fa2819a1cc5drow11_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_4c14b59d_3bab_11ec_b836_fa2819a1cc5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RM

# %%
cbt = create_model('xgboost', cross_validation = False)

# ada = create_model('ada', cross_validation = False)
# lgbm = create_model('lightgbm', cross_validation = False)
# gbr = create_model('gbr', cross_validation = False)
# Out:
#        MAE          MSE       RMSE      R2  RMSLE    MAPE
# 0  62.2407  8525.598633  92.334198  0.3215  0.681  0.1392

# %% [markdown]
# ## 학습

# %%
tuned_cbt = tune_model(cbt, optimize = 'MAE', n_iter = 10)


# tuned_gbr = tune_model(gbr, optimize = 'RMSE', n_iter = 10)
# tuned_ada = tune_model(ada, optimize = 'RMSE', n_iter = 10)
# tuned_lgbm = tune_model(lgbm, optimize = 'RMSE', n_iter = 10)
# Out:
# <style  type="text/css" >
# #T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow10_col0,#T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow10_col1,#T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow10_col2,#T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow10_col3,#T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow10_col4,#T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow10_col5{
#             background:  yellow;
#         }</style><table id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow0_col0" class="data row0 col0" >45.8485</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow0_col1" class="data row0 col1" >4338.3701</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow0_col2" class="data row0 col2" >65.8663</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow0_col3" class="data row0 col3" >0.6251</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow0_col4" class="data row0 col4" >0.1854</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow0_col5" class="data row0 col5" >0.1272</td>
#             </tr>
#             <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow1_col0" class="data row1 col0" >54.5161</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow1_col1" class="data row1 col1" >4991.5127</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow1_col2" class="data row1 col2" >70.6506</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow1_col3" class="data row1 col3" >0.5655</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow1_col4" class="data row1 col4" >0.1577</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow1_col5" class="data row1 col5" >0.1221</td>
#             </tr>
#             <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow2_col0" class="data row2 col0" >62.7988</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow2_col1" class="data row2 col1" >8437.5703</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow2_col2" class="data row2 col2" >91.8562</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow2_col3" class="data row2 col3" >0.4077</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow2_col4" class="data row2 col4" >0.2021</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow2_col5" class="data row2 col5" >0.1415</td>
#             </tr>
#             <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow3_col0" class="data row3 col0" >55.6181</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow3_col1" class="data row3 col1" >4948.7290</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow3_col2" class="data row3 col2" >70.3472</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow3_col3" class="data row3 col3" >0.6002</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow3_col4" class="data row3 col4" >0.5741</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow3_col5" class="data row3 col5" >0.1236</td>
#             </tr>
#             <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow4_col0" class="data row4 col0" >53.4363</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow4_col1" class="data row4 col1" >6563.6396</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow4_col2" class="data row4 col2" >81.0163</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow4_col3" class="data row4 col3" >0.5431</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow4_col4" class="data row4 col4" >0.1836</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow4_col5" class="data row4 col5" >0.1228</td>
#             </tr>
#             <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow5_col0" class="data row5 col0" >48.5378</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow5_col1" class="data row5 col1" >4938.2788</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow5_col2" class="data row5 col2" >70.2729</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow5_col3" class="data row5 col3" >0.5328</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow5_col4" class="data row5 col4" >0.1528</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow5_col5" class="data row5 col5" >0.1115</td>
#             </tr>
#             <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow6_col0" class="data row6 col0" >58.6035</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow6_col1" class="data row6 col1" >6333.1226</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow6_col2" class="data row6 col2" >79.5809</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow6_col3" class="data row6 col3" >0.5433</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow6_col4" class="data row6 col4" >0.2134</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow6_col5" class="data row6 col5" >0.1545</td>
#             </tr>
#             <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow7_col0" class="data row7 col0" >63.0635</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow7_col1" class="data row7 col1" >7148.0571</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow7_col2" class="data row7 col2" >84.5462</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow7_col3" class="data row7 col3" >0.5682</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow7_col4" class="data row7 col4" >0.6595</td>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow7_col5" class="data row7 col5" >0.1575</td>
#             </tr>
#             <tr>
#                         <th id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4d717a7c_3bd7_11ec_a612_fa2819a1cc5drow8_col0" class="data row8 col0" >48

# %%
# blender_specific = blend_models(estimator_list = [tuned_lgbm,tuned_ada,tuned_gbr], optimize = 'MAE')
# Out:
# <style  type="text/css" >
# #T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow10_col0,#T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow10_col1,#T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow10_col2,#T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow10_col3,#T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow10_col4,#T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow10_col5{
#             background:  yellow;
#         }</style><table id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow0_col0" class="data row0 col0" >62.5033</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow0_col1" class="data row0 col1" >8628.8110</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow0_col2" class="data row0 col2" >92.8914</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow0_col3" class="data row0 col3" >0.4157</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow0_col4" class="data row0 col4" >0.9212</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow0_col5" class="data row0 col5" >0.1090</td>
#             </tr>
#             <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow1_col0" class="data row1 col0" >75.0920</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow1_col1" class="data row1 col1" >10655.1177</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow1_col2" class="data row1 col2" >103.2236</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow1_col3" class="data row1 col3" >0.3512</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow1_col4" class="data row1 col4" >0.9260</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow1_col5" class="data row1 col5" >0.1585</td>
#             </tr>
#             <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow2_col0" class="data row2 col0" >64.9317</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow2_col1" class="data row2 col1" >7729.1257</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow2_col2" class="data row2 col2" >87.9154</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow2_col3" class="data row2 col3" >0.4641</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow2_col4" class="data row2 col4" >0.6729</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow2_col5" class="data row2 col5" >0.1561</td>
#             </tr>
#             <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow3_col0" class="data row3 col0" >64.7399</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow3_col1" class="data row3 col1" >9772.1927</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow3_col2" class="data row3 col2" >98.8544</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow3_col3" class="data row3 col3" >0.2649</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow3_col4" class="data row3 col4" >0.6693</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow3_col5" class="data row3 col5" >0.1290</td>
#             </tr>
#             <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow4_col0" class="data row4 col0" >73.4076</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow4_col1" class="data row4 col1" >10183.3260</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow4_col2" class="data row4 col2" >100.9125</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow4_col3" class="data row4 col3" >0.3568</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow4_col4" class="data row4 col4" >0.9337</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow4_col5" class="data row4 col5" >0.1766</td>
#             </tr>
#             <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow5_col0" class="data row5 col0" >77.9250</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow5_col1" class="data row5 col1" >12958.8613</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow5_col2" class="data row5 col2" >113.8370</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow5_col3" class="data row5 col3" >0.4230</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow5_col4" class="data row5 col4" >1.3074</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow5_col5" class="data row5 col5" >0.1511</td>
#             </tr>
#             <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow6_col0" class="data row6 col0" >85.2366</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow6_col1" class="data row6 col1" >15007.1184</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow6_col2" class="data row6 col2" >122.5035</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow6_col3" class="data row6 col3" >0.4020</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow6_col4" class="data row6 col4" >1.4550</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow6_col5" class="data row6 col5" >0.1540</td>
#             </tr>
#             <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow7_col0" class="data row7 col0" >71.1739</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow7_col1" class="data row7 col1" >10865.9423</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow7_col2" class="data row7 col2" >104.2398</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow7_col3" class="data row7 col3" >0.4390</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow7_col4" class="data row7 col4" >1.1335</td>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow7_col5" class="data row7 col5" >0.1427</td>
#             </tr>
#             <tr>
#                         <th id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d7c308dc_3b9d_11ec_a0f0_fa2819a1cc5drow8_col0" class="data row8

# %% [markdown]
# ## 예측 및 결과 제출

# %%
# 중식계 예측

final_model_lunch = finalize_model(tuned_cbt)
pred1 = predict_model(final_model_lunch, data = test_lunch)

# %%
# 석식계 예측(dinner setup 및 모델 생성 후 사용)

test_dinner['중식계'] = pred1['Label']
final_model_dinner = finalize_model(tuned_cbt)
pred2 = predict_model(final_model_dinner, data = test_dinner)

# %%
submission['중식계'] = pred1['Label']
submission['석식계'] = pred2['Label']

# %%
submission.head()
# Out:
#            일자          중식계         석식계
# 0  2021-01-27  1041.003129  391.390526
# 1  2021-01-28   922.015795  455.878211
# 2  2021-01-29   653.542934  268.101406
# 3  2021-02-01  1226.908857  605.436209
# 4  2021-02-02  1022.845271  489.591339

# %%
submission.to_csv('baseline_xgboost.csv', index=False)
